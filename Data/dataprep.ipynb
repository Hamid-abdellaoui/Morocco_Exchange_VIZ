# %%
import pandas as pd

# %%
df=pd.read_csv('./ExportData.csv', delimiter=";")
df.head(5)
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python38\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4,6,8,17,38,44,47,50,53,56,62,65,74,77,83,86,92,98,101,104,107,113,116,119,122,125,128,131) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Code du groupement d'utilisation Libellé du groupement d'utilisation  \
# 0                                 1    ALIMENTATION, BOISSONS ET TABACS
# 1                                 1    ALIMENTATION, BOISSONS ET TABACS
# 2                                 1    ALIMENTATION, BOISSONS ET TABACS
# 3                                 1    ALIMENTATION, BOISSONS ET TABACS
# 4                                 1    ALIMENTATION, BOISSONS ET TABACS
#
#    Code du nouveau produits remarquables  \
# 0                                    101
# 1                                    101
# 2                                    102
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60483 entries, 0 to 60482
# Columns: 132 entries, Code du groupement d'utilisation to Unité complementaire Juin 2021
# dtypes: int64(3), object(129)
# memory usage: 60.9+ MB

# %%
df.columns[:16]
# Out:
# Index(['Code du groupement d'utilisation',
#        'Libellé du groupement d'utilisation',
#        'Code du nouveau produits remarquables',
#        'Libellé du nouveau produits remarquables', 'Code de la section CTCI',
#        'Libellé de la section CTCI', 'Code de la division CTCI',
#        'Libellé de la division CTCI', 'Code du groupe CTCI',
#        'Libellé du groupe CTCI', 'Continent', 'Code du pays',
#        'Libellé du pays', 'Code du flux', 'Libellé du flux',
#        'Poids en KG Janvier 2018'],
#       dtype='object')

# %%
subdf=df.iloc[:,0:15]
subdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60483 entries, 0 to 60482
# Data columns (total 15 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Code du groupement d'utilisation          60483 non-null  int64
#  1   Libellé du groupement d'utilisation       60483 non-null  object
#  2   Code du nouveau produits remarquables     60483 non-null  int64
#  3   Libellé du nouveau produits remarquables  60483 non-null  object
#  4   Code de la section CTCI                   60483 non-null  object
#  5   Libellé de la section CTCI                60483 non-null  object
#  6   Code de la division CTCI                  60483 non-null  object
#  7   Libellé de la division CTCI               60480 non-null  object
#  8   Code du groupe CTCI                       60483 non-null  object
#  9   Libellé du groupe CTCI                    60481 non-null  object
# ...

# %%
subdf.isnull().sum()
# Out:
# Code du groupement d'utilisation             0
# Libellé du groupement d'utilisation          0
# Code du nouveau produits remarquables        0
# Libellé du nouveau produits remarquables     0
# Code de la section CTCI                      0
# Libellé de la section CTCI                   0
# Code de la division CTCI                     0
# Libellé de la division CTCI                  3
# Code du groupe CTCI                          0
# Libellé du groupe CTCI                       2
# Continent                                    0
# Code du pays                                32
# Libellé du pays                              0
# Code du flux                                 0
# Libellé du flux                              0
# dtype: int64

# %%
pays_label=[]
for i in range(len(subdf)):
    if(subdf['Libellé du pays'][i] and subdf['code du pays'][i] ):
        pays_lebel.append({'pays':})
        pays_lebel.append({'pays':})
# Out:
# array(['MAURITANIE', 'SINGAPOUR', 'UKRAINE', 'GUINEE',
#        'REPUBLIQUE DOMINICAINE', 'SRI LANKA', 'MALI', 'SENEGAL', 'QATAR',
#        'BULGARIE', 'GIBRALTAR', 'FEDERATION DE RUSSIE', 'KENYA',
#        'URUGUAY', 'ARABIE SAOUDITE', 'CONGO', 'HONG KONG', 'SUISSE',
#        'DANEMARK', 'FRANCE', 'NIGER', 'REUNION', 'SWAZILAND',
#        'AFRIQUE DU SUD', 'CANADA', 'MEXIQUE', 'REPUBLIQUE DE COREE',
#        'LIBAN', 'OMAN', 'ESPAGNE', 'IRLANDE', 'ITALIE', 'LETTONIE',
#        'TURQUIE', 'ETATS-UNIS', 'EMIRATS ARABES UNIS', 'BELGIQUE',
#        'ALLEMAGNE', 'CAMEROUN', 'EGYPTE', 'SOUDAN', 'GUATEMALA', 'PEROU',
#        'BAHREIN', 'CHINE', 'JAPON', 'AUTRICHE', 'PAYS-BAS', 'POLOGNE',
#        'NAMIBIE', 'ARGENTINE', 'VIET NAM', 'AUSTRALIE', 'PORTUGAL',
#        'AFGHANISTAN', 'MALAISIE', 'THAILANDE', 'TCHAD', 'AVITAILLEMENT',
#        'HONGRIE', 'ALGERIE', 'LIBYE', 'TRINITE-ET-TOBAGO', 'BANGLADESH',
#        'ALBANIE', 'ROYAUME-UNI', 'NOUVELLE-ZELANDE', 'REPUBLIQUE TCHEQUE',
# ...

# %% [markdown]
# As we have a reasonable number of missing values (32) and they are categorical variables , let's create a function to handle th
